# %% [markdown]
# # Steps In Problem Solving
#
# ## EOSC 211
#
# **Week 2 Day 1**
#
# **Learning Objective:** Practice the steps in problem solving using earthquake data.
#
# <img src="quakemap.png" width="500">

# %% [markdown]
# ### Question 1
#
# **Write down the 3 steps in algorithm design mentioned in the text book OR write down some steps you think will be common to problem solving with python (you might have more than 3 steps):**

# %% [markdown]
# 1)
#
# 2)
#
# 3)
#
# 4)

# %% [markdown]
# ### Question 2
# **We want to find the largest earthquake in the Pacific Northwest region in the past year.  The data sheet gives all earthquakes in this area that have a magnitude of at least 4.0.**

# %%
from e211_lib import e211
e211.show_earthquake_data()
# Out:
#         #EventID                 Time  Latitude  Longitude  Depth/km MagType  \
# 0   2.020082e+07  2020-08-19T11:40:59   50.6077  -129.4759     10.00      ML
# 1   2.020082e+07  2020-08-19T11:40:55   50.4094  -130.2877     10.00      Mw
# 2   2.020072e+07  2020-07-22T11:33:21   48.8371  -129.3728     10.00      Mw
# 3   2.020052e+07  2020-05-23T02:14:52   50.3600  -129.2800      8.00       M
# 4   2.020052e+07  2020-05-23T02:14:48   50.1783  -129.8157     10.00      Mw
# 5   2.020051e+07  2020-05-10T04:45:59   49.3278  -127.8000     10.00      Mw
# 6   2.020033e+07  2020-03-29T19:32:02   50.4999  -130.2003     10.00      Mw
# 7   2.020033e+07  2020-03-29T18:28:54   50.4114  -130.2842     10.00      Mw
# 8   2.020031e+07  2020-03-05T23:22:28   50.9881  -130.2942     10.00      Mw
# 9   2.020030e+07  2020-03-02T13:43:21   50.4455  -130.2483     10.00      Mw
# 10  2.020012e+07  2020-01-24T21:35:30   48.5739  -125.1857     38.48      Mw
# 11  2.020011e+07  2020-01-08T20:20:38   50.6677  -130.4762     10.00      Mw
# 12  2.020011e+07  2020-01-06T12:21:43   47.7203  -129.3662     10.00      Mw
# 13  2.020011e+07  2020-01-06T12:12:05   47.6905  -129.0957     10.00      Mw
# 14  2.019123e+07  2019-12-29T08:32:29   50.7334  -130.4852     10.00      Mw
# 15  2.019123e+07  2019-12-25T20:38:50   50.7207  -130.5307     10.00      Mw
# 16  2.019123e+07  2019-12-25T07:31:07   50.2863  -130.2239     10.00      Mw
# 17  2.019123e+07  2019-12-25T03:35:59   50.4851  -130.0955     10.00      Mw
# 18  2.019122e+07  2019-12-23T23:38:25   50.3906  -130.2040     10.00      Mw
# 19  2.019122e+07  2019-12-23T23:14:41   50.2895  -129.7727     10.00      Mw
# 20  2.019122e+07  2019-12-23T22:50:13   50.4613  -129.5008     10.00      Mw
# 21  2.019122e+07  2019-12-23T22:20:02   50.3363  -130.0474     10.00      Mw
# 22  2.019122e+07  2019-12-23T21:05:26   50.2388  -129.8421     10.00      Mw
# 23  2.019122e+07  2019-12-23T20:56:21   50.2903  -130.0174     10.00      Mw
# 24  2.019122e+07  2019-12-23T20:03:20   50.5622  -129.9012     10.00      Mw
# 25  2.019122e+07  2019-12-23T20:00:25   50.6015  -130.0958     10.00      Mw
# 26  2.019122e+07  2019-12-23T19:57:39   50.5347  -130.3156     10.00      Mw
# 27  2.019122e+07  2019-12-23T19:49:41   50.4871  -130.0940     10.00      Mw
# 28  2.019122e+07  2019-12-23T19:26:45   50.3751  -130.0185     10.00      Mw
# 29  2.019122e+07  2019-12-23T19:13:24   50.4146  -130.0350     10.00      Mw
# 30  2.019122e+07  2019-12-23T16:44:10   50.3299  -130.0984     10.00      Mw
#
#     Magnitude                                  EventLocationName
# 0         4.0  Preliminary; 140 KM W OF PORT HARDY, BC/Prelim...
# 1         4.3  200 km W of Port Hardy, BC/200 km O de Port Ha...
# 2         5.2  221 km SW of Port Alice, BC/221 km SO de Port ...
# 3         4.9  Preliminary; 129 km W   of Port Alice, BC/Prel...
# 4         5.1  169 km W of Port Alice, BC/169 km O de Port Al...
# 5         4.8  120 km S of Port Alice, BC/120 km S de Port Al...
# 6         4.3  192 km W of Port Hardy, BC/192 km O de Port Ha...
# 7         4.0  200 km W of Port Hardy, BC/200 km O de Port Ha...
# 8         4.0  198 km W of Port Hardy, BC/198 km O de Port Ha...
# 9         4.4  196 km W of Port Hardy, BC/196 km O de Port Ha...
# 10        4.5    29 km S of Bamfield, BC/29 km S de Bamfield, BC
# 11        4.6  209 km W of Port Hardy, BC/209 km O de Port Ha...
# 12        4.1    300 km SW of Tofino, BC/300 km SO de Tofino, BC
# 13        4.0    285 km SW of Tofino, BC/285 km SO de Tofino, BC
# 14        4.1  210 km W of Port Hardy, BC/210 km O de Port Ha...
# 15        4.8  213 km W of Port Hardy, BC/213 km O de Port Ha...
# 16        4.0  197 km W of Port Alice, BC/197 km O de Port Al...
# 17        6.2  185 km W of Port Hardy, BC/185 km O de Port Ha...
# 18        4.9  194 km W of Port Hardy, BC/194 km O de Port Ha...
# 19        4.0  165 km W of Port Alice, BC/165 km O de Port Al...
# 20        4.1  144 km W of Port Hardy, BC/144 km O de Port Ha...
# 21        4.4  184 km W of Port Alice, BC/184 km O de Port Al...
# 22        4.9  171 km W of Port Alice, BC/171 km O de Port Al...
# 23        6.1  182 km W of Port Alice, BC/182 km O de Port Al...
# 24        4.2  170 km W of Port Hardy, BC/170 km O de Port Ha...
# 25        4.7  183 km W of Port Hardy, BC/183 km O de Port Ha...
# 26        4.9  200 km W of Port Hardy, BC/200 km O de Port Ha...
# 27        6.0  185 km W of Port Hardy, BC/185 km O de Port Ha...
# 28        4.0  182 km W of Port Alice, BC/182 km O de Port Al...
# 29        5.6  182 km W of Port Hardy, BC/182 km O de Port Ha...
# 30        5.1  188 km W of Port Alice, BC/188 km O de Port Al...

# %% [markdown]
# source: http://www.earthquakescanada.nrcan.gc.ca/
#
# **A) We want to design an *algorithm* to find the largest earthquake. Describe in words the *input* and *output* of your algorithm**

# %% [markdown]
# Input:
#
# Output:

# %% [markdown]
# **B).  Below, document the procedure you went through to get to your answer for the value of the output above.  <br> HINT:**  you need to think about what your brain actually does when it finds the largest # in a list

# %% [markdown]
# your answer here

# %% [markdown]
# ### Question 3
#
# **The following is a *Python* code snippet:**

# %%
mag1 = 4.9
mag2 = 5.3
if mag1 > mag2:
    max_mag = mag1
else:
    max_mag = mag2

# %% [markdown]
# **Identify the following:**

# %% [markdown]
# A) Variable names:
#
# B) Operators:
#
# C) Reserved words:
#
# D) Special characters:
